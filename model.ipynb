# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
dataset = pd.read_csv(r"D:\Internship projects\covtype\covtype.csv")

# %%
dataset.head()
# Out:
#    Elevation  Aspect  Slope  ...  Soil_Type39  Soil_Type40  Cover_Type
# 0       2596      51      3  ...            0            0           5
# 1       2590      56      2  ...            0            0           5
# 2       2804     139      9  ...            0            0           2
# 3       2785     155     18  ...            0            0           2
# 4       2595      45      2  ...            0            0           5
#
# [5 rows x 55 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 581012 entries, 0 to 581011
# Data columns (total 55 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   Elevation                           581012 non-null  int64
#  1   Aspect                              581012 non-null  int64
#  2   Slope                               581012 non-null  int64
#  3   Horizontal_Distance_To_Hydrology    581012 non-null  int64
#  4   Vertical_Distance_To_Hydrology      581012 non-null  int64
#  5   Horizontal_Distance_To_Roadways     581012 non-null  int64
#  6   Hillshade_9am                       581012 non-null  int64
#  7   Hillshade_Noon                      581012 non-null  int64
#  8   Hillshade_3pm                       581012 non-null  int64
#  9   Horizontal_Distance_To_Fire_Points  581012 non-null  int64
#  10  Wilderness_Area1                    581012 non-null  int64
# ...

# %%
dataset.describe()
# Out:
#            Elevation         Aspect  ...    Soil_Type40     Cover_Type
# count  581012.000000  581012.000000  ...  581012.000000  581012.000000
# mean     2959.365301     155.656807  ...       0.015060       2.051471
# std       279.984734     111.913721  ...       0.121791       1.396504
# min      1859.000000       0.000000  ...       0.000000       1.000000
# 25%      2809.000000      58.000000  ...       0.000000       1.000000
# 50%      2996.000000     127.000000  ...       0.000000       2.000000
# 75%      3163.000000     260.000000  ...       0.000000       2.000000
# max      3858.000000     360.000000  ...       1.000000       7.000000
#
# [8 rows x 55 columns]

# %%
dataset.shape
# Out:
# (581012, 55)

# %%
dataset.isnull().sum()
# Out:
# Elevation                             0
# Aspect                                0
# Slope                                 0
# Horizontal_Distance_To_Hydrology      0
# Vertical_Distance_To_Hydrology        0
# Horizontal_Distance_To_Roadways       0
# Hillshade_9am                         0
# Hillshade_Noon                        0
# Hillshade_3pm                         0
# Horizontal_Distance_To_Fire_Points    0
# Wilderness_Area1                      0
# Wilderness_Area2                      0
# Wilderness_Area3                      0
# Wilderness_Area4                      0
# Soil_Type1                            0
# Soil_Type2                            0
# Soil_Type3                            0
# Soil_Type4                            0
# Soil_Type5                            0
# Soil_Type6                            0
# Soil_Type7                            0
# Soil_Type8                            0
# Soil_Type9                            0
# ...

# %%
dataset['Cover_Type'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cover_Type'>

# %%
numeric_df = dataset.iloc[:,:10]
plt.figure(figsize=(10,8))
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# Model Training

# %%
y = dataset['Cover_Type']
X = dataset.drop(columns='Cover_Type')

# %%
print(X.shape)
# Out:
# (581012, 54)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
print(X_train.shape, X_test.shape)
# Out:
# (464809, 54) (116203, 54)

# %%
model = RandomForestClassifier(n_estimators=100, random_state=2, n_jobs=-1)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=2)

# %%
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy*100:.2f}%")
print("__________________________________________________________________\n")
confusion = confusion_matrix(y_test, y_pred)
print(f"confusion_matrix: {confusion}")
# Out:
# Model Accuracy: 95.54%
# __________________________________________________________________
#
# confusion_matrix: [[40231  2294     0     0    12     0    93]
#  [ 1231 55063    95     3    54    73    16]
#  [    3   118  6841    29     8   120     0]
#  [    0     0    68   468     0    16     0]
#  [   23   357    18     0  1497     5     0]
#  [    4    68   233    10     3  3095     0]
#  [  204    28     0     0     0     0  3822]]

# %%
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt=True)
#
# File c:\Users\Ali's PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\matrix.py:459, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     457 if square:
#     458     ax.set_aspect("equal")
# --> 459 plotter.plot(ax, cbar_ax, kwargs)
#     460 return ax
#
# File c:\Users\Ali's PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\matrix.py:352, in _HeatMapper.plot(self, ax, cax, kws)
#     350 # Annotate the cells with the formatted values
#     351 if self.annot:
# --> 352     self._annotate_heatmap(ax, mesh)
#
# ...
